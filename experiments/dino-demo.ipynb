# %%
import sys
sys.path.insert(0, '../models/dino/')

# %%
from DINO_Classifier import DINO_Classifier

# %%
dino = DinoClassifier()
dino_filepath = "Dino-classifier-epoch008"
dino.load_state_dict(torch.load(dino_filepath, weights_only=True))
